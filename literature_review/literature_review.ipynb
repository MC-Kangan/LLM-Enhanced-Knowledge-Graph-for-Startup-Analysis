# %%
import os
import numpy as np
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain.output_parsers.json import SimpleJsonOutputParser
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain.schema import StrOutputParser
from dotenv import load_dotenv
import json

# %%
# Function to read a JSON file
def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# %%
doc_list = sorted(os.listdir('reading_resource/json_summary'))

# %%
index_list = list(np.arange(0, len(doc_list), 40)) + [len(doc_list)]
index_list
# Out:
# [0, 40, 80, 120, 160, 199]

# %%
paper_chunk_lst = []
for i in range(len(index_list)-1):
    start = index_list[i]
    end = index_list[i+1]
    print(start, end)

    paper_chunk = ''
    for index in range(start, end):
        paper_data = read_json_file(f'reading_resource/json_summary/{doc_list[index]}')
        paper_chunk += 'Title: ' + paper_data["Title"] + '\n'
        paper_chunk += 'Summary: ' + paper_data["Summary"] + '\n'
        paper_chunk += '-------------------' +'\n'
    
    paper_chunk_lst.append(paper_chunk)
# Out:
# 0 40
# 40 80
# 80 120
# 120 160
# 160 199

# %%
print(paper_chunk_lst[0])
# Out:
# Title: A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases
# Summary: - The study investigates the effectiveness of Large Language Models (LLMs) for question answering on enterprise SQL databases.
# - There is a lack of suitable Text-to-SQL benchmarks for enterprise settings, making it difficult to assess LLM accuracy.
# - The research explores the potential of Knowledge Graphs (KGs) to enhance LLM-based question answering by providing business context.
# - A new benchmark is introduced, featuring an enterprise SQL schema in the insurance domain, various enterprise queries, and a contextual layer with an ontology and mappings for a knowledge graph.
# - The primary finding indicates that GPT-4 achieves an accuracy of 16% for zero-shot prompts on SQL databases.
# - Accuracy improves to 54% when questions are asked over a Knowledge Graph representation of the SQL database.
# - The study concludes that investing in Knowledge Graphs significantly enhances the accuracy of LLM-powered question answering systems.
# -------------------
# Title: A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models
# Summary: - Zero-shot link prediction (ZSLP) aims to identify relations between entities in knowledge graphs without prior examples.
# - Existing methods rely on auxiliary information, which can be limited, and struggle with predicting tail entities based solely on semantic similarities.
# - Large Language Models (LLMs) show potential for zero-shot relation prediction but are hindered by their inability to utilize all possible paths between entities.
# - The study introduces the Condensed Transition Graph Framework for Zero-Shot Link Prediction (CTLP), which efficiently encodes path information in linear time complexity.
# - CTLP features a condensed transition graph encoder with theoretical guarantees on coverage, expressiveness, and efficiency, learned through a transition graph contrastive learning strategy.
# - A soft instruction tuning method is developed to map all-path embeddings to LLM inputs.
# - Experimental results demonstrate that CTLP achieves state-of-the-art performance on three standard ZSLP datasets.
# -------------------
# Title: A Graph-to-Text Approach to Knowledge-Grounded Response Generation in Human-Robot Interaction
# Summary: - The paper explores the use of knowledge graphs in situated dialogue, specifically in human-robot interaction.
# - A novel conversational model is introduced that utilizes a graph-based representation of the dialogue state.
# - The dialogue state knowledge graph is continuously updated with inputs from robot sensors, including linguistic, situated, and multimodal data.
# - The model incorporates additional modules for enhanced spatial understanding.
# - A graph-to-text mechanism is employed to convert the dialogue state graph into natural language responses.
# - This conversion uses parameterized functions, with parameters optimized through Wizard-of-Oz interactions.
# - The text representation of the dialogue state is integrated into a large language model to generate agent responses.
# - An empirical user study with a humanoid robot evaluated the effectiveness of the graph-to-text mechanism.
# - Results showed a statistically significant improvement in the perceived factuality of the robot's responses when using the graph-to-text approach compared to a baseline of semantic triples.
# -------------------
# Title: A Multimodal Ecological Civilization Pattern Recommendation Method Based on Large Language Models and Knowledge Graph
# Summary: - The Ecological Civilization Pattern Recommendation System (ECPRS) aims to recommend ecological civilization patterns for sustainable development and reducing regional disparities.
# - Current recommendation methods are inadequate for geographical contexts due to:
#   - Spatial heterogeneity of regions, requiring consideration of climate, topography, and vegetation.
#   - Underutilization of abstract features of ecological civilization patterns, leading to poor embedding representations.
# - The proposed ECPR-MML method addresses these limitations by:
#   - Constructing a knowledge graph using the UGPIG method to incorporate spatial heterogeneity features.
#   - Utilizing Large Language Models (LLMs) to generate multimodal features (text and images) for ecological civilization patterns.
#   - Integrating these multimodal features to create semantically rich representations.
# - Experimental results show that ECPR-MML outperforms state-of-the-art models, with F1@5 scores:
#   - 2.11% higher than the best existing models.
#   - 2.02% higher than NGCF.
#   - 1.16% higher than UGPIG.
# - Multimodal data enhances recommendation performance, but LLM-generated data is less effective than real data.
# -------------------
# Title: A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs
# Summary: - Conducted a mixed-methods study on the role of large language models (LLMs) in visual exploration and analysis of knowledge graphs (KGs).
# - Engaged 20 professionals from industry, government, and academia who work with KGs and LLMs.
# - Key findings indicate a strong desire for LLMs to:
#   - Facilitate data retrieval from KGs via joint query construction.
#   - Identify interesting relationships in KGs through multi-turn conversations.
#   - Generate on-demand visualizations to enhance trust in LLM outputs.
# - Participants preferred a chat-based 'widget' integrated into their existing analysis workflows, allowing interaction with visualizations.
# - When reviewing LLM outputs, a combination of annotated visuals (e.g., subgraphs, tables) and summarizing text was favored.
# - Concerns raised included:
#   - LLMs' ability to maintain semantic intent in translating natural language to KG queries.
#   - Risks of LLMs 'hallucinating' false data.
#   - Challenges in creating effective prompts for LLMs.
# - The study contributes a preliminary roadmap for designing LLM-driven knowledge graph exploration systems and highlights future opportunities in this area.
# -------------------
# Title: A Survey of Knowledge Enhanced Pre-trained Language Models
# Summary: - Pre-trained Language Models (PLMs) show strong performance in various NLP tasks due to self-supervised learning on large text corpora.
# - Despite their effectiveness, PLMs have limitations, particularly in reasoning abilities, due to a lack of external knowledge.
# - The paper reviews Knowledge Enhanced Pre-trained Language Models (KE-PLMs) to address these limitations.
# - It introduces taxonomies for Natural Language Understanding (NLU) and Natural Language Generation (NLG) to clarify the application of knowledge in these tasks.
# - For NLU, knowledge is categorized into four types: linguistic knowledge, text knowledge, knowledge graph (KG), and rule knowledge.
# - KE-PLMs for NLG are classified into KG-based and retrieval-based methods.
# - The paper concludes with suggestions for promising future directions in the development of KE-PLMs.
# -------------------
# Title: A knowledge representation approach for construction contract knowledge modeling
# Summary: - Large language models (LLMs) offer potential for automating construction contract management, reducing human errors and saving time and costs.
# - LLMs may generate inaccurate content due to insufficient domain expertise.
# - The paper introduces the Nested Contract Knowledge Graph (NCKG) to structure expert-driven contract knowledge and improve contract management.
# - NCKG features a nested knowledge representation framework and an ontology, along with an implementation method.
# - A LLM-assisted contract review pipeline is presented, enhanced by external knowledge from NCKG.
# - The pipeline demonstrates promising performance in contract risk reviewing, highlighting the effective integration of LLMs and knowledge graphs for reliable contract management.
# -------------------
# Title: AbsPyramid: Benchmarking the Abstraction Ability of Language Models with a Unified Entailment Graph
# Summary: - Abstraction ability is crucial for human intelligence but is under-explored in language models.
# - The paper introduces AbsPyramid, a unified entailment graph containing 221K textual descriptions of abstraction knowledge.
# - Unlike existing resources that focus on nouns or verbs in simplified events, AbsPyramid encompasses abstract knowledge for three components of diverse events.
# - The framework aims to evaluate the abstraction ability of language models in an open domain.
# - Experimental results indicate that current large language models (LLMs) struggle with understanding abstraction knowledge in zero-shot and few-shot scenarios.
# - Training on AbsPyramid allows LLMs to develop basic abstraction abilities and generalize to new, unseen events.
# - The benchmark is shown to be comprehensive, enhancing LLM performance on two previous abstraction tasks.
# -------------------
# Title: Advancing Biomedical Text Mining with Community Challenges
# Summary: - The accumulation of textual data in biomedical research has increased significantly from various sources, making manual processing inefficient.
# - Biomedical text mining (natural language processing) has gained attention as a solution to analyze this complex data.
# - Community challenge evaluation competitions have fostered innovation and collaboration in biomedical text mining.
# - The article reviews recent advances in community challenges specific to Chinese biomedical text mining.
# - It collects information on evaluation tasks, including data sources and task types.
# - A systematic summary and comparative analysis of various tasks is conducted, such as named entity recognition, relation extraction, and text classification.
# - The potential clinical applications of these tasks are summarized from a translational informatics perspective.
# - The article discusses the contributions and limitations of community challenges and suggests future directions, particularly in the context of large language models.
# -------------------
# Title: An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration
# Summary: - Large Language Models (LLMs) face challenges in practical applications, such as hallucinations, knowledge updating issues, and limited transparency in reasoning.
# - The study proposes a collaborative training-free reasoning scheme that integrates Knowledge Graphs (KG) with LLMs.
# - The approach involves LLMs iteratively exploring KGs to retrieve relevant knowledge subgraphs for reasoning support.
# - LLMs combine implicit knowledge with the retrieved subgraph while clearly explaining their reasoning process.
# - This cooperative method enhances the reliability of knowledge-based reasoning and allows for tracing reasoning results.
# - Experimental results demonstrate significant improvements, with over a 10% increase on the QALD10 dataset compared to the best baseline and state-of-the-art methods.
# - The study aims to provide a reference for future research on the integration of KGs and LLMs to improve LLMs' capabilities in addressing complex problems.
# -------------------
# Title: An In-Context Schema Understanding Method for Knowledge Base Question Answering
# Summary: - The Knowledge Base Question Answering (KBQA) task involves answering natural language questions using a knowledge base.
# - Large Language Models (LLMs) have shown strong language understanding capabilities for this task.
# - A significant challenge for LLMs is managing the vast and diverse schemas of knowledge bases.
# - Existing methods generate drafts of logic forms without schema-specific details and then inject schema information through an additional module.
# - The proposed In-Context Schema Understanding (ICSU) method allows LLMs to directly comprehend schemas using in-context learning.
# - ICSU utilizes schema-related annotated examples to provide schema information to LLMs.
# - Three example retrieval strategies are investigated: based on raw questions, anonymized questions, and generated SPARQL queries.
# - Experimental results indicate that ICSU performs competitively against baseline methods on the KQA Pro and WebQSP datasets.
# -------------------
# Title: Answer Candidate Type Selection: Text-to-Text Language Model for Closed Book Question Answering Meets Knowledge Graphs
# Summary: - Pre-trained Text-to-Text Language Models (e.g., T5, BART) show promise in Knowledge Graph Question Answering (KGQA).
# - The effectiveness of these models diminishes for questions involving less popular entities.
# - The paper introduces a novel approach that enhances the pre-trained Text-to-Text QA system.
# - The proposed method involves filtering and re-ranking generated candidates based on their types from the Wikidata "instance_of" property.
# - The approach is described as simple yet effective in improving the quality of answers.
# -------------------
# Title: AttacKG+:Boosting Attack Knowledge Graph Construction with Large Language Models
# Summary: - The paper addresses the construction of attack knowledge graphs from textual cyber threat intelligence (CTI) reports.
# - Previous methods for constructing these graphs have limitations in generalization and require expertise in model design and tuning.
# - The authors propose a fully automatic framework called AttacKG+, utilizing Large Language Models (LLMs) for improved performance.
# - The framework consists of four modules: rewriter, parser, identifier, and summarizer, all implemented through instruction prompting and in-context learning with LLMs.
# - An upgraded and comprehensive attack knowledge schema is introduced, representing cyber attacks as temporally unfolding events with three layers: behavior graph, MITRE TTP labels, and state summary.
# - Evaluation results show that the framework effectively meets information needs in threat event analysis, accurately extracts information, and supports downstream security practices like attack reconstruction.
# - The authors plan to release all code and datasets upon acceptance of the paper.
# -------------------
# Title: AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models
# Summary: - Objective: Development of AutoRD, an end-to-end system for automating information extraction from clinical text regarding rare diseases.
# - Methodology: AutoRD is a software pipeline that includes data preprocessing, entity extraction, relation extraction, entity calibration, and knowledge graph construction, utilizing large language models (LLMs) and medical knowledge graphs from open-source ontologies.
# - Performance Evaluation:
#   - Overall F1 score of AutoRD is 47.3%, showing a 14.4% improvement over the base LLM.
#   - Entity extraction F1 score: 56.1% (rare_disease: 83.5%, disease: 35.8%, symptom_and_sign: 46.1%, anaphor: 67.5%).
#   - Relation extraction F1 score: 38.6% (produces: 34.7%, increases_risk_of: 12.4%, is_a: 37.4%, is_acronym: 44.1%, is_synonym: 16.3%, anaphora: 57.5%).
# - Qualitative Results: Knowledge graph construction performance is commendable.
# - Discussion: AutoRD showcases the potential of LLMs in rare disease detection, enhanced by the integration of ontologies.
# - Conclusion: AutoRD effectively automates the extraction of rare disease information and knowledge graph construction, demonstrating the robust application of LLMs in healthcare.
# -------------------
# Title: Automated Construction of Theme-specific Knowledge Graphs
# Summary: - Existing knowledge graphs (KGs) face challenges in information granularity and timeliness, affecting their effectiveness in specialized and rapidly evolving contexts.
# - The paper proposes a theme-specific knowledge graph (ThemeKG) constructed from a theme-specific corpus.
# - An unsupervised framework for ThemeKG construction, named TKGCon, is introduced to generate high-quality KGs with salient entities and relations.
# - The framework utilizes an entity ontology from Wikipedia and generates candidate relations using Large Language Models (LLMs).
# - The process involves mapping extracted entity pairs to the ontology, retrieving candidate relations, and consolidating them with context.
# - Directly prompting GPT-4 for theme-specific KGs results in inaccuracies in entity identification and relation clarity.
# - The proposed step-by-step construction method outperforms GPT-4, consistently identifying accurate entities and relations.
# - Experimental results demonstrate that TKGCon excels in evaluations compared to various KG construction baselines.
# -------------------
# Title: Automatic Question-Answer Generation for Long-Tail Knowledge
# Summary: - Pretrained Large Language Models (LLMs) are effective for open-domain Question Answering (QA) but struggle with uncommon long-tail knowledge (tail entities).
# - Existing QA datasets are limited and require significant human effort to create, leading to a scarcity of resources for studying LLM performance on tail entities.
# - The paper proposes an automatic method to generate specialized QA datasets focused on tail entities.
# - It identifies and discusses the research challenges associated with this approach.
# - Extensive experiments are conducted using pretrained LLMs on the newly generated long-tail QA datasets.
# - The performance of LLMs is compared with and without the use of external resources, such as Wikipedia and Wikidata knowledge graphs.
# -------------------
# Title: Benchmarking Large Language Models in Complex Question Answering Attribution using Knowledge Graphs
# Summary: - The paper addresses the challenge of providing citations for generated statements in question answering.
# - Current automatic evaluation methods for attribution, often based on Large Language Models (LLMs), are inadequate.
# - There is a need for better recognition of subtle differences in attributions and complex relationships between citations and statements.
# - The authors introduce fine-grained categories for measuring attribution: supportive, insufficient, contradictory, and irrelevant.
# - A new benchmark called Complex Attributed Question Answering (CAQA) is developed, utilizing knowledge graphs to generate attributions for question-answer pairs.
# - Analysis shows that existing evaluators struggle with fine-grained attribution and complex citation-statement reasoning.
# - The CAQA benchmark, validated with human annotations, is proposed as a valuable tool for selecting and developing LLM attribution evaluators.
# -------------------
# Title: Benchmarking the Abilities of Large Language Models for RDF Knowledge Graph Creation and Comprehension: How Well Do LLMs Speak Turtle?
# Summary: - Large Language Models (LLMs) are rapidly improving in natural language processing and coding tasks.
# - Their performance with formal languages, particularly in knowledge graph engineering, is not well-studied.
# - A set of five tasks was developed to assess LLMs' abilities to parse, understand, analyze, and create knowledge graphs in Turtle syntax.
# - These tasks vary in complexity and can scale with problem size, integrated into the LLM-KG-Bench evaluation system.
# - The evaluation included four commercial LLMs (GPT-3.5, GPT-4, Claude 1.3, Claude 2.0) and two free offline models (GPT4All Vicuna, GPT4All Falcon 13B).
# - The analysis provides insights into the strengths and weaknesses of LLMs in RDF knowledge graph engineering using Turtle representation.
# - Findings indicate that while newer commercial models perform better with Turtle language, they struggle with strict output formatting constraints, which are essential in this context.
# -------------------
# Title: Beyond Isolation: Multi-Agent Synergy for Improving Knowledge Graph Construction
# Summary: - Knowledge graph construction (KGC) involves extracting entities, relations, and events.
# - Traditional approaches view large language models (LLMs) as isolated task solvers.
# - The paper introduces a new framework called CooperKGC, which promotes collaborative processing.
# - CooperKGC forms a KGC collaboration team to simultaneously tackle entity, relation, and event extraction tasks.
# - Experiments show that collaboration among diverse agents in CooperKGC leads to better results than isolated processes.
# - The framework enhances knowledge selection, correction, and aggregation through multiple rounds of interaction.
# -------------------
# Title: BiasKG: Adversarial Knowledge Graphs to Induce Bias in Large Language Models
# Summary: - Modern large language models (LLMs) possess extensive world knowledge, enhancing their performance in commonsense reasoning and knowledge-intensive tasks.
# - LLMs can also learn and perpetuate social biases, posing potential societal risks.
# - Existing mitigation strategies for LLM safety are questioned regarding their effectiveness in eliminating social biases.
# - The study introduces a novel methodology that utilizes knowledge graph augmented generation to attack language models.
# - Natural language stereotypes are refactored into a knowledge graph, and adversarial strategies are employed to provoke biased responses from various language models.
# - The findings indicate that the proposed method increases bias across all tested models, including those with safety measures in place.
# - This highlights the necessity for further research in AI safety and exploration of adversarial approaches in this context.
# -------------------
# Title: Biomedical Entity Linking with Triple-aware Pre-Training
# Summary: - Linking biomedical entities is crucial for tasks like text mining and question answering in biomedical natural language processing.
# - Current large language models (LLMs) struggle with linking biomedical entities due to their sparse distribution in training texts.
# - LLMs lack awareness of high-level semantic connections between different biomedical entities, which hinders concept identification across contexts.
# - Recent approaches have attempted to integrate knowledge graph (KG) information into LLMs but often overlook relational knowledge or cause catastrophic forgetting.
# - The proposed framework aims to pre-train a generative LLM using a corpus synthesized from a knowledge graph.
# - Evaluation results did not confirm the advantages of incorporating synonym, description, or relational information in the training process.
# -------------------
# Title: Biomedical knowledge graph-optimized prompt generation for large language models
# Summary: - Large Language Models (LLMs) face challenges in knowledge-intensive fields like biomedicine.
# - Pre-training and domain-specific fine-tuning require significant computational resources and expertise.
# - The study introduces a Knowledge Graph-based Retrieval Augmented Generation (KG-RAG) framework using the SPOKE biomedical knowledge graph.
# - KG-RAG optimizes token usage by employing minimal graph schema for context extraction and embedding methods for context pruning.
# - This optimization leads to over 50% reduction in token consumption without sacrificing accuracy.
# - The framework enhances LLM performance across various biomedical prompts, providing responses grounded in established knowledge with accurate provenance.
# - Benchmarking on curated datasets showed a 71% performance improvement for the Llama-2 model on a challenging multiple-choice question dataset.
# - KG-RAG also improved the performance of proprietary models like GPT-3.5 and GPT-4.
# - The framework effectively combines explicit and implicit knowledge from knowledge graphs and LLMs, enhancing adaptability for domain-specific questions in a cost-effective manner.
# -------------------
# Title: Breaking the Barrier: Utilizing Large Language Models for Industrial Recommendation Systems through an Inferential Knowledge Graph
# Summary: - Recommendation systems in e-commerce face challenges due to reliance on historical data and user feedback, which limits capturing user intent transitions.
# - Existing Knowledge Base (KB)-based models struggle to adapt to new items and the changing e-commerce environment.
# - The proposed solution, LLM-KERec, is a Large Language Model based Complementary Knowledge Enhanced Recommendation System.
# - LLM-KERec features an entity extractor that unifies concept terms from item and user information.
# - It generates entity pairs based on popularity and specific strategies to provide reliable prior knowledge.
# - A complementary knowledge graph is constructed by the large language model to determine relationships between entity pairs.
# - The system includes a complementary recall module and an Entity-Entity-Item (E-E-I) weight decision model to refine ranking scores using real exposure-click samples.
# - Extensive experiments on three industry datasets show significant performance improvements over existing recommendation approaches.
# - LLM-KERec enhances user engagement by recommending complementary items.
# - Overall, the model effectively addresses limitations of traditional systems by incorporating complementary knowledge and adapting to user intent and new items in the evolving e-commerce landscape.
# -------------------
# Title: Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery
# Summary: - Sourcing new manufacturing partners is essential for system integrators to improve agility and mitigate risks through supply chain diversification.
# - Advanced large language models, like ChatGPT, show promise but often lack accuracy in domain-specific areas such as manufacturing service discovery.
# - This research investigates the use of Knowledge Graphs combined with ChatGPT to assist clients in identifying small manufacturing enterprises.
# - A method is proposed that integrates bottom-up ontology with machine learning to create a Manufacturing Service Knowledge Graph from various data sources, including digital footprints of small manufacturers in North America.
# - The Knowledge Graph and graph embedding vectors are utilized to address complex queries in the digital supply chain, offering improved reliability and interpretability.
# - The approach is scalable to millions of entities, potentially forming a global Manufacturing Service Knowledge Network Graph that connects various Knowledge Graphs across industries and regions.
# - The dataset developed includes over 13,000 manufacturers' weblinks, services, certifications, and location types, and is now publicly accessible.
# -------------------
# Title: CADReN: Contextual Anchor-Driven Relational Network for Controllable Cross-Graphs Node Importance Estimation
# Summary: - Node Importance Estimation (NIE) is essential for integrating external information into Large Language Models via Retriever-Augmented Generation.
# - Traditional NIE methods are limited by their focus on static, single-graph characteristics and lack adaptability to new graphs and user-specific needs.
# - The proposed method, CADReN, introduces a Contextual Anchor (CA) mechanism to evaluate node importance based on both structural and semantic features in Knowledge Graphs (KGs).
# - CADReN demonstrates superior performance in cross-graph NIE tasks and exhibits zero-shot prediction capabilities.
# - The method matches the performance of existing models in single-graph NIE tasks.
# - Two new datasets, RIC200 and WK1K, are introduced and open-sourced for cross-graph NIE research, serving as valuable resources for future studies.
# -------------------
# Title: CR-LT-KGQA: A Knowledge Graph Question Answering Dataset Requiring Commonsense Reasoning and Long-Tail Knowledge
# Summary: - Knowledge graph question answering (KGQA) aims to provide factual answers to natural language questions using knowledge graphs.
# - Existing KGQA datasets have two main limitations:
#   1. They do not require commonsense reasoning for answers.
#   2. They focus on popular entities, allowing large language models (LLMs) to answer without utilizing the knowledge graph.
# - This work introduces a new KGQA dataset that incorporates commonsense reasoning and targets long-tail entities, where LLMs are prone to hallucination.
# - The new dataset, named Commonsense Reasoning and Long-Tail (CR-LT) KGQA, includes two subtasks: question answering and claim verification.
# - CR-LT-KGQA is developed by extending existing reasoning datasets (StrategyQA and CREAK) over Wikidata.
# - Baseline evaluations show that current KGQA methods are inadequate due to their inability to support commonsense inference, resulting in high hallucination rates among LLMs.
# - The CR-LT KGQA dataset presents significant challenges for LLMs, highlighting the need for improved methodologies in commonsense KGQA research for accurate answers regarding long-tail entities.
# -------------------
# Title: Call Me When Necessary: LLMs can Efficiently and Faithfully Reason over Structured Environments
# Summary: - Large Language Models (LLMs) can effectively reason over structured environments like knowledge graphs and tables, requiring multi-hop reasoning.
# - Previous methods involved LLMs incrementally building reasoning paths through step-by-step interactions with the environment.
# - The proposed framework, Reasoning-Path-Editing (Readi), allows LLMs to generate a reasoning path from a query and edit it only when necessary.
# - Readi provides feedback to correct the reasoning path if errors occur during the reasoning process.
# - Experimental results demonstrate Readi's effectiveness, outperforming previous LLM-based methods by significant margins (e.g., 9.1% Hit@1 improvement on WebQSP).
# - Readi's performance is comparable to state-of-the-art fine-tuned methods and shows substantial improvements over vanilla LLMs (14.9% increase on CWQ).
# - The code for Readi will be made available online.
# -------------------
# Title: Can Knowledge Graphs Reduce Hallucinations in LLMs? : A Survey
# Summary: - Contemporary large language models (LLMs) often produce hallucinations due to knowledge gaps.
# - Researchers are exploring various strategies to enhance LLMs by integrating external knowledge to reduce hallucinations and improve reasoning accuracy.
# - Utilizing knowledge graphs as a source of external information has shown promising results in this context.
# - The survey reviews knowledge-graph-based augmentation techniques for LLMs, focusing on their effectiveness in mitigating hallucinations.
# - Methods are systematically categorized into three main groups, with methodological comparisons and performance evaluations provided.
# - The survey also discusses current trends, challenges, and potential future research directions in this area.
# -------------------
# Title: Can large language models build causal graphs?
# Summary: - Building causal graphs is a labor-intensive task requiring expert consultation and literature review.
# - Large language models (LLMs) have the potential to simplify this process by automatically scoring edges in causal graphs.
# - LLMs are sensitive to the choice of probing words, context, and prompts used by the user.
# - This study evaluates the effectiveness of LLMs as a complementary tool in the development of causal graphs.
# -------------------
# Title: Can large language models generate salient negative statements?
# Summary: - The study investigates the capability of large language models (LLMs) to generate interesting negative statements about real-world entities.
# - It employs zero- and k-shot unconstrained probes and compares the results with traditional negation generation methods, including pattern-based extractions and knowledge-graph inferences, as well as crowdsourced gold statements.
# - The evaluation focuses on the correctness and salience of the generated negative statements across various domains.
# - Results indicate that guided probes enhance the quality of generated negatives compared to zero-shot approaches.
# - Despite improvements, LLMs still face challenges with factuality, often producing ambiguous statements or negatives that convey positive meanings.
# -------------------
# Title: Causal Reasoning and Large Language Models: Opening a New Frontier for Causality
# Summary: - The debate on the causal capabilities of large language models (LLMs) has significant implications for their use in critical fields like medicine, science, law, and policy.
# - The study explores different types of causal reasoning tasks and addresses issues of construct and measurement validity.
# - LLM-based methods achieve state-of-the-art accuracies on various causal benchmarks, outperforming existing algorithms:
#   - 97% accuracy in pairwise causal discovery (13 points gain).
#   - 92% accuracy in counterfactual reasoning (20 points gain).
#   - 86% accuracy in determining necessary and sufficient causes in vignettes.
# - LLMs demonstrate unpredictable failure modes, and the study offers techniques to interpret their robustness.
# - LLMs utilize knowledge and methods that complement non-LLM approaches, enabling capabilities previously thought to be exclusive to humans, such as generating causal graphs and identifying causal context from natural language.
# - The authors propose using LLMs alongside existing causal methods to leverage human domain knowledge and reduce the effort required for causal analysis.
# - Existing causal methods can help formalize, validate, and communicate LLM reasoning, especially in high-stakes scenarios.
# - LLMs enhance the understanding of causal mechanisms and facilitate the translation between natural language and formal methods, potentially advancing the research and practice of causality.
# -------------------
# Title: Chain of History: Learning and Forecasting with LLMs for Temporal Knowledge Graph Completion
# Summary: - The paper addresses Temporal Knowledge Graph Completion (TKGC), focusing on predicting missing event links at future timestamps using temporal structural knowledge.
# - It presents a comprehensive approach to utilizing Large Language Models (LLMs) for reasoning within temporal knowledge graphs, offering a transferable pipeline.
# - The study highlights LLMs' ability to understand the structural information of key nodes in historical data.
# - An extensive investigation is conducted on the impact of various inherent factors in LLMs, particularly regarding challenges in understanding reverse logic.
# - A parameter-efficient fine-tuning strategy is employed to align LLMs with TKGC task requirements, enhancing the learning of essential knowledge.
# - Experimental results demonstrate that the proposed framework outperforms or matches existing methods across multiple metrics on well-known datasets.
# - The research includes extensive ablation studies and comparisons with advanced commercial LLMs to identify critical factors affecting LLM performance in structured temporal knowledge inference tasks.
# -------------------
# Title: Chain-of-History Reasoning for Temporal Knowledge Graph Forecasting
# Summary: - Temporal Knowledge Graph (TKG) forecasting predicts future facts based on historical data.
# - Recent graph-based models excel in structural information but lack semantic understanding.
# - LLM-based TKG prediction models have emerged but face three main challenges:
#   1. They focus only on first-order history, neglecting high-order historical information.
#   2. LLMs struggle with reasoning under heavy historical information loads.
#   3. LLMs have limited temporal reasoning capabilities for TKG prediction.
# - The proposed solution, Chain-of-History (CoH) reasoning, addresses these challenges by:
#   - Exploring high-order histories step-by-step to enhance LLMs' use of historical information.
#   - Serving as a plug-and-play module to improve graph-based models' performance in TKG prediction.
# - Extensive experiments on three datasets validate the effectiveness of CoH.
# -------------------
# Title: ChatGraph: Interpretable Text Classification by Converting ChatGPT Knowledge to Graphs
# Summary: - ChatGPT demonstrates superior performance in various natural language processing (NLP) tasks but has limitations in finetuning and interpretability.
# - The proposed framework enhances ChatGPT's application for specific tasks, such as text classification, while improving interpretability.
# - It involves a knowledge graph extraction task to derive structured knowledge from raw data using ChatGPT.
# - The extracted knowledge is transformed into a graph, which is then used to train an interpretable linear classifier for predictions.
# - Experiments on four datasets show that the proposed method significantly outperforms direct use of ChatGPT for text classification.
# - The method also offers a more transparent decision-making process compared to previous text classification approaches.
# -------------------
# Title: ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models
# Summary: - Knowledge Base Question Answering (KBQA) involves answering natural language questions using large-scale knowledge bases, focusing on knowledge retrieval and semantic parsing.
# - Three main challenges in KBQA are identified: inefficient knowledge retrieval, the negative impact of retrieval errors on semantic parsing, and the complexity of existing methods.
# - The paper introduces ChatKBQA, a new generate-then-retrieve framework that first generates logical forms using fine-tuned large language models (LLMs) and then retrieves and replaces entities and relations through an unsupervised method.
# - ChatKBQA improves both the generation and retrieval processes directly.
# - Experimental results demonstrate that ChatKBQA achieves state-of-the-art performance on standard KBQA datasets, specifically WebQSP and CWQ.
# - This work presents a new paradigm for integrating LLMs with knowledge graphs for interpretable and knowledge-driven question answering.
# - The code for ChatKBQA is publicly available.
# -------------------
# Title: Clue-Guided Path Exploration: An Efficient Knowledge Base Question-Answering Framework with Low Computational Resource Consumption
# Summary: - Large language models (LLMs) exhibit impressive capabilities but struggle with knowledge updates, leading to inaccuracies with unfamiliar queries.
# - Existing methods integrating knowledge graphs with LLMs often place high demands on the models, which is unsuitable for lower-capacity LLMs.
# - The paper introduces the Clue-Guided Path Exploration framework (CGPE), which efficiently combines a knowledge base with an LLM while reducing the demands on the model's capabilities.
# - CGPE uses clues from the question to systematically explore the necessary knowledge path in the knowledge base, mimicking human knowledge retrieval methods.
# - Experiments on open-source datasets show that CGPE outperforms previous approaches and is particularly effective for LLMs with fewer parameters.
# - Notably, even the 6 billion parameter ChatGLM3 can achieve performance comparable to GPT-4 in some cases.
# - The results indicate that CGPE requires minimal invocation frequency on LLMs, leading to reduced computational overhead.
# - This research provides significant practical value for organizations and individuals with limited computational resources.
# -------------------
# Title: Complex Logical Reasoning over Knowledge Graphs using Large Language Models
# Summary: - Reasoning over knowledge graphs (KGs) is complex due to intricate relationships and logic.
# - Current methods use geometries for entity embedding but struggle with complex queries and specific datasets.
# - The paper introduces LARK (Language-guided Abstract Reasoning over Knowledge graphs), a decoupled approach combining contextual KG search and logical query reasoning.
# - LARK leverages graph extraction algorithms and large language models (LLMs) to enhance reasoning capabilities.
# - Experimental results show LARK outperforms state-of-the-art KG reasoning methods on benchmark datasets, especially for complex queries.
# - Performance improves with the size of the underlying LLM, allowing integration of advancements in LLMs for KG reasoning.
# - The work offers a new direction for tackling challenges in complex KG reasoning and suggests avenues for future research.
# -------------------
# Title: Complex Reasoning over Logical Queries on Commonsense Knowledge Graphs
# Summary: - Event commonsense reasoning involves understanding relationships between events and inferring implicit contexts.
# - Data scarcity hinders language models from generating commonsense inferences for complex event interactions.
# - The study introduces COM2 (COMplex COMmonsense), a new dataset designed to enhance commonsense reasoning.
# - COM2 is created by sampling multi-hop logical queries from an existing commonsense knowledge graph (CSKG).
# - Queries are verbalized into multiple-choice and text generation questions using handcrafted rules and large language models.
# - Experiments demonstrate that language models trained on COM2 show significant improvements in complex reasoning abilities.
# - Enhanced zero-shot performance is observed in both in-domain and out-of-domain tasks for question answering and generative commonsense reasoning.
# - The approach does not require expensive human annotations.
# - Code and data for COM2 are publicly available.
# -------------------
# Title: Conceptual Engineering Using Large Language Models
# Summary: - The paper presents a method for implementing classification procedures using a large language model, based on Jennifer Nado's definition of conceptual engineering.
# - The method is applied to evaluate concept definitions from two significant conceptual engineering projects: the International Astronomical Union's redefinition of "PLANET" and Haslanger's analysis of "WOMAN."
# - The findings discuss the implications of this work for both the theory and practice of conceptual engineering.
# - The code and data related to the research are available on GitHub.
# -------------------
# Title: Construction and Application of Materials Knowledge Graph in Multidisciplinary Materials Science via Large Language Model
# Summary: - The integration of artificial intelligence with materials science addresses challenges in discovering and integrating new materials from extensive literature.
# - Traditional experimental methods are costly and time-consuming, hindering rapid innovation.
# - The article introduces the Materials Knowledge Graph (MKG), which employs advanced natural language processing and large language models.
# - MKG extracts and organizes a decade's worth of research into structured triples, comprising 162,605 nodes and 731,772 edges.
# - Information is categorized into comprehensive labels (e.g., Name, Formula, Application) based on a meticulously designed ontology, enhancing data usability.
# - MKG facilitates efficient link prediction through network-based algorithms, reducing reliance on traditional experimental methods.
# - This structured approach streamlines materials research and establishes a foundation for more advanced science knowledge graphs.
# -------------------

# %%
def research_paper_recommendation(paper_info, custom_prompt):
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", custom_prompt),
            ("human", f"Please read the text containing paper's information:\n\n{paper_info}"),
            ("human", """
                Here are the rules that you need to adhere:
                ## Rules:
                - Make sure to answer in the standard text format.
                - DO NOT HALLUCINATE.
             """),
        ]
    )
    
    llm = ChatOpenAI(openai_api_key=os.getenv('OPENAI_KEY'),
                    temperature=0, 
                    model_name="gpt-4o")

    llm_chain = prompt | llm | StrOutputParser()

    response = llm_chain.invoke({'input': paper_info})
    return response

# %%
custom_prompt1 = """You are a helpful assistant that can help me to find relevant research paper for my thesis project.
                          The topic of my thesis is 'Leveraging Large Language Models for Knowledge Graph Construction'.
                          I need you to read a text of research paper title and summary abstract and return me a list of research paper titles that might be relevant to my project.
                          I am interested in the topic of: 
                          - Using large language model for knowledge graph construction
                          - Build knowledge graph with custom or industry-specific dataset
                          - Survey or review paper that covers the technology of knowledge graph and large language model
                          Return the response in this string format: "title_1; title_2; title_3, ..."
                          Only return the article title that are highly relevant to my research interest.
                          """

# %% [markdown]
# ### GPT4O-MINI OUTPUT

# %%
recommendation_paper_list = []
for i in range(len(paper_chunk_lst)):
    response = research_paper_recommendation(paper_chunk_lst[i], custom_prompt1)
    print(response.split(';'))
    recommendation_paper_list += response.split(';')
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases", ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models', ' A Graph-to-Text Approach to Knowledge-Grounded Response Generation in Human-Robot Interaction', ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs', ' A Survey of Knowledge Enhanced Pre-trained Language Models', ' A knowledge representation approach for construction contract knowledge modeling', ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration', ' Automated Construction of Theme-specific Knowledge Graphs', ' AttacKG+:Boosting Attack Knowledge Graph Construction with Large Language Models', ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models', ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery', ' Can Knowledge Graphs Reduce Hallucinations in LLMs? : A Survey', ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models', ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models', ' Construction and Application of Materials Knowledge Graph in Multidisciplinary Materials Science via Large Language Model.']
# ['Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models', ' Construction of Paired Knowledge Graph-Text Datasets Informed by Cyclic Evaluation', ' Context Matters: Pushing the Boundaries of Open-Ended Answer Generation with Graph-Structured Knowledge Context', ' Conversational Question Answering with Reformulations over Knowledge Graph', ' CuriousLLM: Elevating Multi-Document QA with Reasoning-Infused Knowledge Graph Prompting', " DALK: Dynamic Co-Augmentation of LLMs and KG to answer Alzheimer's Disease Questions with Scientific Literature", ' DIVKNOWQA: Assessing the Reasoning Ability of LLMs via Open-Domain Question Answering over Knowledge Base and Text', ' Developing a Scalable Benchmark for Assessing Large Language Models in Knowledge Graph Engineering', ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models', ' Effective Bug Detection in Graph Database Engines: An LLM-based Approach', ' EffiQA: Efficient Question-Answering with Strategic Multi-Model Collaboration on Knowledge Graphs', ' Efficient Knowledge Infusion via KG-LLM Alignment', ' Enhancing Large Language Models with Pseudo- and Multisource- Knowledge Graphs for Open-ended Question Answering', ' Evaluating Class Membership Relations in Knowledge Graphs using Large Language Models', ' Evaluating Large Language Models for Structured Science Summarization in the Open Research Knowledge Graph', ' Evaluating Large Language Models in Semantic Parsing for Conversational Question Answering over Knowledge Graphs', ' Evaluating and Enhancing Large Language Models for Conversational Reasoning on Knowledge Graphs', ' Exploring Large Language Models for Knowledge Graph Completion', ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction', ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction', ' GLaM: Fine-Tuning Large Language Models for Domain Knowledge Graph Alignment via Neighborhood Partitioning and Generative Subgraph Encoding', ' GPT4Graph: Can Large Language Models Understand Graph Structured Data ? An Empirical Evaluation and Benchmarking.']
# ['Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering', ' Generations of Knowledge Graphs: The Crazy Ideas and the Business Impact', ' GraphGPT: Graph Instruction Tuning for Large Language Models', ' Graph Agent: Explicit Reasoning Agent for Graphs', ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph', ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction', ' KGValidator: A Framework for Automatic Validation of Knowledge Graph Construction', ' Knowledge Graph Prompting for Multi-Document Question Answering', ' Knowledge Graphs Meet Multi-Modal Learning: A Comprehensive Survey', ' Knowledge Graphs as Context Sources for LLM-Based Explanations of Learning Recommendations.']
# ['LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities', ' LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT', ' Leveraging A Medical Knowledge Graph into Large Language Models for Diagnosis Prediction', ' Logic Query of Thoughts: Guiding Large Language Models to Answer Complex Logic Queries with Knowledge Graphs', ' Making Large Language Models Perform Better in Knowledge Graph Completion', ' On the Evolution of Knowledge Graphs: A Survey and Perspective', ' PHALM: Building a Knowledge Graph from Scratch by Prompting Humans and a Language Model', ' Prompting Large Language Models with Knowledge Graphs for Question Answering Involving Long-tail Facts', ' Reasoning on Efficient Knowledge Paths: Knowledge Graph Guides Large Language Model for Domain Question Answering.']
# ['RelBERT: Embedding Relations with Language Models', ' Relations Prediction for Knowledge Graph Completion using Large Language Models', ' Retrieve-Rewrite-Answer: A KG-to-Text Enhanced LLMs Framework for Knowledge Graph Question Answering', ' Right for Right Reasons: Large Language Models for Verifiable Commonsense Knowledge Graph Question Answering', ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph', ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment', ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models', ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models', ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction', ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs', ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models.']

# %%
recommendation_paper_list
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases",
#  ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models',
#  ' A Graph-to-Text Approach to Knowledge-Grounded Response Generation in Human-Robot Interaction',
#  ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs',
#  ' A Survey of Knowledge Enhanced Pre-trained Language Models',
#  ' A knowledge representation approach for construction contract knowledge modeling',
#  ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration',
#  ' Automated Construction of Theme-specific Knowledge Graphs',
#  ' AttacKG+:Boosting Attack Knowledge Graph Construction with Large Language Models',
#  ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models',
#  ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery',
#  ' Can Knowledge Graphs Reduce Hallucinations in LLMs? : A Survey',
#  ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models',
#  ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models',
#  ' Construction and Application of Materials Knowledge Graph in Multidisciplinary Materials Science via Large Language Model.',
#  'Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models',
#  ' Construction of Paired Knowledge Graph-Text Datasets Informed by Cyclic Evaluation',
#  ' Context Matters: Pushing the Boundaries of Open-Ended Answer Generation with Graph-Structured Knowledge Context',
#  ' Conversational Question Answering with Reformulations over Knowledge Graph',
#  ' CuriousLLM: Elevating Multi-Document QA with Reasoning-Infused Knowledge Graph Prompting',
#  " DALK: Dynamic Co-Augmentation of LLMs and KG to answer Alzheimer's Disease Questions with Scientific Literature",
#  ' DIVKNOWQA: Assessing the Reasoning Ability of LLMs via Open-Domain Question Answering over Knowledge Base and Text',
#  ' Developing a Scalable Benchmark for Assessing Large Language Models in Knowledge Graph Engineering',
#  ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models',
#  ' Effective Bug Detection in Graph Database Engines: An LLM-based Approach',
#  ' EffiQA: Efficient Question-Answering with Strategic Multi-Model Collaboration on Knowledge Graphs',
#  ' Efficient Knowledge Infusion via KG-LLM Alignment',
#  ' Enhancing Large Language Models with Pseudo- and Multisource- Knowledge Graphs for Open-ended Question Answering',
#  ' Evaluating Class Membership Relations in Knowledge Graphs using Large Language Models',
#  ' Evaluating Large Language Models for Structured Science Summarization in the Open Research Knowledge Graph',
#  ' Evaluating Large Language Models in Semantic Parsing for Conversational Question Answering over Knowledge Graphs',
#  ' Evaluating and Enhancing Large Language Models for Conversational Reasoning on Knowledge Graphs',
#  ' Exploring Large Language Models for Knowledge Graph Completion',
#  ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction',
#  ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction',
#  ' GLaM: Fine-Tuning Large Language Models for Domain Knowledge Graph Alignment via Neighborhood Partitioning and Generative Subgraph Encoding',
#  ' GPT4Graph: Can Large Language Models Understand Graph Structured Data ? An Empirical Evaluation and Benchmarking.',
#  'Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering',
#  ' Generations of Knowledge Graphs: The Crazy Ideas and the Business Impact',
#  ' GraphGPT: Graph Instruction Tuning for Large Language Models',
#  ' Graph Agent: Explicit Reasoning Agent for Graphs',
#  ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph',
#  ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction',
#  ' KGValidator: A Framework for Automatic Validation of Knowledge Graph Construction',
#  ' Knowledge Graph Prompting for Multi-Document Question Answering',
#  ' Knowledge Graphs Meet Multi-Modal Learning: A Comprehensive Survey',
#  ' Knowledge Graphs as Context Sources for LLM-Based Explanations of Learning Recommendations.',
#  'LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities',
#  ' LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT',
#  ' Leveraging A Medical Knowledge Graph into Large Language Models for Diagnosis Prediction',
#  ' Logic Query of Thoughts: Guiding Large Language Models to Answer Complex Logic Queries with Knowledge Graphs',
#  ' Making Large Language Models Perform Better in Knowledge Graph Completion',
#  ' On the Evolution of Knowledge Graphs: A Survey and Perspective',
#  ' PHALM: Building a Knowledge Graph from Scratch by Prompting Humans and a Language Model',
#  ' Prompting Large Language Models with Knowledge Graphs for Question Answering Involving Long-tail Facts',
#  ' Reasoning on Efficient Knowledge Paths: Knowledge Graph Guides Large Language Model for Domain Question Answering.',
#  'RelBERT: Embedding Relations with Language Models',
#  ' Relations Prediction for Knowledge Graph Completion using Large Language Models',
#  ' Retrieve-Rewrite-Answer: A KG-to-Text Enhanced LLMs Framework for Knowledge Graph Question Answering',
#  ' Right for Right Reasons: Large Language Models for Verifiable Commonsense Knowledge Graph Question Answering',
#  ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph',
#  ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment',
#  ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models',
#  ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models',
#  ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction',
#  ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs',
#  ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models.']

# %% [markdown]
# ### GPT4O OUTPUT

# %%
recommendation_paper_list = []
for i in range(len(paper_chunk_lst)):
    response = research_paper_recommendation(paper_chunk_lst[i], custom_prompt1)
    print(response.split(';'))
    recommendation_paper_list += response.split(';')
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases", ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models', ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs', ' A Survey of Knowledge Enhanced Pre-trained Language Models', ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration', ' AttacKG+:Boosting Attack Knowledge Graph Construction with Large Language Models', ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models', ' Automated Construction of Theme-specific Knowledge Graphs', ' Benchmarking Large Language Models in Complex Question Answering Attribution using Knowledge Graphs', ' Benchmarking the Abilities of Large Language Models for RDF Knowledge Graph Creation and Comprehension: How Well Do LLMs Speak Turtle?', ' Beyond Isolation: Multi-Agent Synergy for Improving Knowledge Graph Construction', ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery', ' Can Knowledge Graphs Reduce Hallucinations in LLMs? : A Survey', ' Chain of History: Learning and Forecasting with LLMs for Temporal Knowledge Graph Completion', ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models', ' Clue-Guided Path Exploration: An Efficient Knowledge Base Question-Answering Framework with Low Computational Resource Consumption', ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models']
# ['Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models', ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models', ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction', ' Exploring Large Language Models for Knowledge Graph Completion', ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction', ' Enhancing Large Language Models with Pseudo- and Multisource- Knowledge Graphs for Open-ended Question Answering', ' Efficient Knowledge Infusion via KG-LLM Alignment', ' Evaluating Large Language Models in Semantic Parsing for Conversational Question Answering over Knowledge Graphs', ' Evaluating and Enhancing Large Language Models for Conversational Reasoning on Knowledge Graphs', ' Explainability for Large Language Models: A Survey']
# ['Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering', ' Generations of Knowledge Graphs: The Crazy Ideas and the Business Impact', ' GraphGPT: Graph Instruction Tuning for Large Language Models', ' Graph Agent: Explicit Reasoning Agent for Graphs', ' Harnessing the Power of Large Language Model for Uncertainty Aware Graph Processing', ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction', ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph', ' Knowledge Graph Enhanced Large Language Model Editing']
# ['LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT', ' LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities', ' Large Language Models and Knowledge Graphs: Opportunities and Challenges', ' On the Evolution of Knowledge Graphs: A Survey and Perspective']
# ['Relations Prediction for Knowledge Graph Completion using Large Language Models', ' Retrieve-Rewrite-Answer: A KG-to-Text Enhanced LLMs Framework for Knowledge Graph Question Answering', ' Right for Right Reasons: Large Language Models for Verifiable Commonsense Knowledge Graph Question Answering', ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph', ' Structured prompt interrogation and recursive extraction of semantics (SPIRES): A method for populating knowledge bases using zero-shot learning', ' Survey on Factuality in Large Language Models: Knowledge, Retrieval and Domain-Specificity', ' TechGPT-2.0: A large language model project to solve the task of knowledge graph construction', ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment', ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models', ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models', ' Unlocking the Power of Large Language Models for Entity Alignment', ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction', ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs', ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models']

# %%
recommendation_paper_list
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases",
#  ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models',
#  ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs',
#  ' A Survey of Knowledge Enhanced Pre-trained Language Models',
#  ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration',
#  ' AttacKG+:Boosting Attack Knowledge Graph Construction with Large Language Models',
#  ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models',
#  ' Automated Construction of Theme-specific Knowledge Graphs',
#  ' Benchmarking Large Language Models in Complex Question Answering Attribution using Knowledge Graphs',
#  ' Benchmarking the Abilities of Large Language Models for RDF Knowledge Graph Creation and Comprehension: How Well Do LLMs Speak Turtle?',
#  ' Beyond Isolation: Multi-Agent Synergy for Improving Knowledge Graph Construction',
#  ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery',
#  ' Can Knowledge Graphs Reduce Hallucinations in LLMs? : A Survey',
#  ' Chain of History: Learning and Forecasting with LLMs for Temporal Knowledge Graph Completion',
#  ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models',
#  ' Clue-Guided Path Exploration: An Efficient Knowledge Base Question-Answering Framework with Low Computational Resource Consumption',
#  ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models',
#  'Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models',
#  ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models',
#  ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction',
#  ' Exploring Large Language Models for Knowledge Graph Completion',
#  ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction',
#  ' Enhancing Large Language Models with Pseudo- and Multisource- Knowledge Graphs for Open-ended Question Answering',
#  ' Efficient Knowledge Infusion via KG-LLM Alignment',
#  ' Evaluating Large Language Models in Semantic Parsing for Conversational Question Answering over Knowledge Graphs',
#  ' Evaluating and Enhancing Large Language Models for Conversational Reasoning on Knowledge Graphs',
#  ' Explainability for Large Language Models: A Survey',
#  'Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering',
#  ' Generations of Knowledge Graphs: The Crazy Ideas and the Business Impact',
#  ' GraphGPT: Graph Instruction Tuning for Large Language Models',
#  ' Graph Agent: Explicit Reasoning Agent for Graphs',
#  ' Harnessing the Power of Large Language Model for Uncertainty Aware Graph Processing',
#  ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction',
#  ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph',
#  ' Knowledge Graph Enhanced Large Language Model Editing',
#  'LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT',
#  ' LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities',
#  ' Large Language Models and Knowledge Graphs: Opportunities and Challenges',
#  ' On the Evolution of Knowledge Graphs: A Survey and Perspective',
#  'Relations Prediction for Knowledge Graph Completion using Large Language Models',
#  ' Retrieve-Rewrite-Answer: A KG-to-Text Enhanced LLMs Framework for Knowledge Graph Question Answering',
#  ' Right for Right Reasons: Large Language Models for Verifiable Commonsense Knowledge Graph Question Answering',
#  ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph',
#  ' Structured prompt interrogation and recursive extraction of semantics (SPIRES): A method for populating knowledge bases using zero-shot learning',
#  ' Survey on Factuality in Large Language Models: Knowledge, Retrieval and Domain-Specificity',
#  ' TechGPT-2.0: A large language model project to solve the task of knowledge graph construction',
#  ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment',
#  ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models',
#  ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models',
#  ' Unlocking the Power of Large Language Models for Entity Alignment',
#  ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction',
#  ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs',
#  ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models']

# %%
custom_prompt2 = """You are a helpful assistant that can help me to find relevant research paper for my thesis project.
                    The topic of my thesis is 'Leveraging Large Language Models for Knowledge Graph Construction'.
                    I need you to read a text of research paper title and summary abstract and return me a list of research paper titles that might be relevant to my project.
                    I am interested in the topic of: 
                    - Using large language model for knowledge graph construction
                    - Build domian-specific knowledge graph with custom or industry-specific dataset
                    - Construction of knowledge graph using pre-defined ontologies and relationships
                    Return the response in this string format: "title_1; title_2; title_3, ..."
                    Only return the article title that are highly relevant to my research interest.
                    """

# %%
recommendation_paper_list = []
for i in range(len(paper_chunk_lst)):
    response = research_paper_recommendation(paper_chunk_lst[i], custom_prompt2)
    print(response.split(';'))
    recommendation_paper_list += response.split(';')
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases", ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models', ' A Graph-to-Text Approach to Knowledge-Grounded Response Generation in Human-Robot Interaction', ' A Multimodal Ecological Civilization Pattern Recommendation Method Based on Large Language Models and Knowledge Graph', ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs', ' A knowledge representation approach for construction contract knowledge modeling', ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration', ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models', ' Automated Construction of Theme-specific Knowledge Graphs', ' Benchmarking Large Language Models in Complex Question Answering Attribution using Knowledge Graphs', ' Benchmarking the Abilities of Large Language Models for RDF Knowledge Graph Creation and Comprehension: How Well Do LLMs Speak Turtle?', ' Beyond Isolation: Multi-Agent Synergy for Improving Knowledge Graph Construction', ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery', ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models', ' Clue-Guided Path Exploration: An Efficient Knowledge Base Question-Answering Framework with Low Computational Resource Consumption', ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models', ' Construction and Application of Materials Knowledge Graph in Multidisciplinary Materials Science via Large Language Model']
# ['Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models', ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models', ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction', ' Efficient Knowledge Infusion via KG-LLM Alignment', ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction', ' Exploring Large Language Models for Knowledge Graph Completion']
# ['Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering', ' Generative retrieval-augmented ontologic graph and multi-agent strategies for interpretive large language model-based materials design', ' GraphGPT: Graph Instruction Tuning for Large Language Models', ' Graph Agent: Explicit Reasoning Agent for Graphs', ' Harnessing the Power of Large Language Model for Uncertainty Aware Graph Processing', ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction', ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph', ' Knowledge Graph Completion Models are Few-shot Learners: An Empirical Study of Relation Labeling in E-commerce with LLMs', ' Knowledge Graph Enhanced Large Language Model Editing', ' Knowledge Graph Large Language Model (KG-LLM) for Link Prediction', ' Knowledge Graph Prompting for Multi-Document Question Answering', ' KnowGPT: Knowledge Graph based Prompting for Large Language Models', ' Knowledge Solver: Teaching LLMs to Search for Domain Knowledge from Knowledge Graphs']
# ['LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT', ' LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities', ' Large Language Models Can Better Understand Knowledge Graphs Than We Thought', ' Large Language Models Meet Knowledge Graphs to Answer Factoid Questions', ' Making Large Language Models Perform Better in Knowledge Graph Completion', ' Prompting Large Language Models with Knowledge Graphs for Question Answering Involving Long-tail Facts', ' Reasoning on Efficient Knowledge Paths: Knowledge Graph Guides Large Language Model for Domain Question Answering']
# ['Relations Prediction for Knowledge Graph Completion using Large Language Models', ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph', ' Structured prompt interrogation and recursive extraction of semantics (SPIRES): A method for populating knowledge bases using zero-shot learning', ' TechGPT-2.0: A large language model project to solve the task of knowledge graph construction', ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment', ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models', ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models', ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction', ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs', ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models']

# %%
recommendation_paper_list
# Out:
# ["A Benchmark to Understand the Role of Knowledge Graphs on Large Language Model's Accuracy for Question Answering on Enterprise SQL Databases",
#  ' A Condensed Transition Graph Framework for Zero-shot Link Prediction with Large Language Models',
#  ' A Graph-to-Text Approach to Knowledge-Grounded Response Generation in Human-Robot Interaction',
#  ' A Multimodal Ecological Civilization Pattern Recommendation Method Based on Large Language Models and Knowledge Graph',
#  ' A Preliminary Roadmap for LLMs as Assistants in Exploring, Analyzing, and Visualizing Knowledge Graphs',
#  ' A knowledge representation approach for construction contract knowledge modeling',
#  ' An Enhanced Prompt-Based LLM Reasoning Scheme via Knowledge Graph-Integrated Collaboration',
#  ' AutoRD: An Automatic and End-to-End System for Rare Disease Knowledge Graph Construction Based on Ontologies-enhanced Large Language Models',
#  ' Automated Construction of Theme-specific Knowledge Graphs',
#  ' Benchmarking Large Language Models in Complex Question Answering Attribution using Knowledge Graphs',
#  ' Benchmarking the Abilities of Large Language Models for RDF Knowledge Graph Creation and Comprehension: How Well Do LLMs Speak Turtle?',
#  ' Beyond Isolation: Multi-Agent Synergy for Improving Knowledge Graph Construction',
#  ' Building A Knowledge Graph to Enrich ChatGPT Responses in Manufacturing Service Discovery',
#  ' ChatKBQA: A Generate-then-Retrieve Framework for Knowledge Base Question Answering with Fine-tuned Large Language Models',
#  ' Clue-Guided Path Exploration: An Efficient Knowledge Base Question-Answering Framework with Low Computational Resource Consumption',
#  ' Complex Logical Reasoning over Knowledge Graphs using Large Language Models',
#  ' Construction and Application of Materials Knowledge Graph in Multidisciplinary Materials Science via Large Language Model',
#  'Construction of Hyper-Relational Knowledge Graphs Using Pre-Trained Large Language Models',
#  ' Docs2KG: Unified Knowledge Graph Construction from Heterogeneous Documents Assisted by Large Language Models',
#  ' Extract, Define, Canonicalize: An LLM-based Framework for Knowledge Graph Construction',
#  ' Efficient Knowledge Infusion via KG-LLM Alignment',
#  ' From human experts to machines: An LLM supported approach to ontology and knowledge graph construction',
#  ' Exploring Large Language Models for Knowledge Graph Completion',
#  'Generate-on-Graph: Treat LLM as both Agent and KG in Incomplete Knowledge Graph Question Answering',
#  ' Generative retrieval-augmented ontologic graph and multi-agent strategies for interpretive large language model-based materials design',
#  ' GraphGPT: Graph Instruction Tuning for Large Language Models',
#  ' Graph Agent: Explicit Reasoning Agent for Graphs',
#  ' Harnessing the Power of Large Language Model for Uncertainty Aware Graph Processing',
#  ' Iterative Zero-Shot LLM Prompting for Knowledge Graph Construction',
#  ' KnowledgeNavigator: Leveraging Large Language Models for Enhanced Reasoning over Knowledge Graph',
#  ' Knowledge Graph Completion Models are Few-shot Learners: An Empirical Study of Relation Labeling in E-commerce with LLMs',
#  ' Knowledge Graph Enhanced Large Language Model Editing',
#  ' Knowledge Graph Large Language Model (KG-LLM) for Link Prediction',
#  ' Knowledge Graph Prompting for Multi-Document Question Answering',
#  ' KnowGPT: Knowledge Graph based Prompting for Large Language Models',
#  ' Knowledge Solver: Teaching LLMs to Search for Domain Knowledge from Knowledge Graphs',
#  'LLM-assisted Knowledge Graph Engineering: Experiments with ChatGPT',
#  ' LLMs for Knowledge Graph Construction and Reasoning: Recent Capabilities and Future Opportunities',
#  ' Large Language Models Can Better Understand Knowledge Graphs Than We Thought',
#  ' Large Language Models Meet Knowledge Graphs to Answer Factoid Questions',
#  ' Making Large Language Models Perform Better in Knowledge Graph Completion',
#  ' Prompting Large Language Models with Knowledge Graphs for Question Answering Involving Long-tail Facts',
#  ' Reasoning on Efficient Knowledge Paths: Knowledge Graph Guides Large Language Model for Domain Question Answering',
#  'Relations Prediction for Knowledge Graph Completion using Large Language Models',
#  ' SPARQL Generation: an analysis on fine-tuning OpenLLaMA for Question Answering over a Life Science Knowledge Graph',
#  ' Structured prompt interrogation and recursive extraction of semantics (SPIRES): A method for populating knowledge bases using zero-shot learning',
#  ' TechGPT-2.0: A large language model project to solve the task of knowledge graph construction',
#  ' Two Heads Are Better Than One: Integrating Knowledge from Knowledge Graphs and Large Language Models for Entity Alignment',
#  ' Two-stage Generative Question Answering on Temporal Knowledge Graph Using Large Language Models',
#  ' UniOQA: A Unified Framework for Knowledge Graph Question Answering with Large Language Models',
#  ' UrbanKGent: A Unified Large Language Model Agent Framework for Urban Knowledge Graph Construction',
#  ' Using Large Language Models for Zero-Shot Natural Language Generation from Knowledge Graphs',
#  ' Zero- and Few-Shots Knowledge Graph Triplet Extraction with Large Language Models']
